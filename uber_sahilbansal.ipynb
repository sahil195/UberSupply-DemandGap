# %%
#importing the libraries
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
# importing data from uber file
uber = pd.read_csv(r"C:\Users\Lenovo\Desktop\Uber Request Data.csv")

# %%
#correcting req timestamp column to single format
uber['Request timestamp new'] = pd.to_datetime(uber['Request timestamp'],dayfirst=True )
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
#correcting drop timestamp column to single format
uber['Drop timestamp new'] = pd.to_datetime(uber['Drop timestamp'],dayfirst=True )
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
#dropping unnecessary column 
uber=uber.drop(['Request timestamp'], axis=1)
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
#dropping unnecessary column 
uber=uber.drop(['Drop timestamp'], axis=1)
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
#creating a separate column for hours 
uber['Request_time_hours']=uber['Request timestamp new'].apply(lambda x: x.hour)
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
#creating separate column for drop time hours
uber['Drop_time_hours']=uber['Drop timestamp new'].apply(lambda x: x.hour)
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
# creating separate column for drop time day
uber['Drop_time_day']=uber['Drop timestamp new'].dt.dayofweek
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
# creating separate column for drop time
uber['Drop_time']=uber['Drop timestamp new'].dt.time
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
# creating separate column for request time
uber['Req_time']=uber['Request timestamp new'].dt.time
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
# creating separate column for request day
uber['Req_day']=uber['Request timestamp new'].dt.dayofweek
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
#creating separate column for request date
uber['Req_date']=uber['Request timestamp new'].dt.date
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
# creating separate column for drop date
uber['Drop_date']=uber['Drop timestamp new'].dt.date
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
#UDF to allot each time to categories of the day i.e EarlyMorning, Morning, Evening, Afternoon
import datetime as dt
def allotTimeslot(time):
    currentTime = time #etime.strptime(time,"%H:%M:%S")
    MorningStartTime = dt.datetime.strptime("05:00:00","%H:%M:%S").time()
    AfternoonStartTime = dt.datetime.strptime("12:00:00","%H:%M:%S").time()
    EveningStartTime = dt.datetime.strptime("17:00:00","%H:%M:%S").time()
    NightStartTime = dt.datetime.strptime("22:00:00","%H:%M:%S").time()
    LateNightStartTime = dt.datetime.strptime("01:00:00","%H:%M:%S").time()
    
    if((currentTime >= MorningStartTime) & (currentTime < AfternoonStartTime)):
        return "Morning"
    elif((currentTime >= AfternoonStartTime) & (currentTime < EveningStartTime)):
        return "Afternoon"
    elif((currentTime >= EveningStartTime) & (currentTime < NightStartTime)):
        return "Evening"
    elif((currentTime >= NightStartTime) | (currentTime < LateNightStartTime)):
        return "Night"    
    elif((currentTime >= LateNightStartTime) | (currentTime < MorningStartTime)):
        return "Late Night"

# %%
#Adding another column to add timeslot of the day
uber['RequestTimeSlotCategory'] = uber['Req_time'].apply(allotTimeslot)
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
# Checking all the categories being present and no extra value in the RequestTimeSlotCategory column
uber.groupby('RequestTimeSlotCategory').sum()
# Out:
#                          Request id  Driver id  Request_time_hours  \
# RequestTimeSlotCategory
# Afternoon                   2743357    87141.0               11301
# Evening                     8677330   141228.0               44542
# Late Night                  1373282    34417.0                1371
# Morning                     7653895   300710.0               19029
# Night                       2381566    48712.0               11150
#
#                          Drop_time_hours  Drop_time_day  Req_day
# RequestTimeSlotCategory
# Afternoon                         7252.0          903.0     1618
# Evening                          15551.0         1576.0     4682
# Late Night                         682.0          354.0      998
# Morning                           9313.0         2096.0     5006
# Night                             3662.0          719.0     1260

# %%
# Function to get the commute time from the city to airport and vice versa
def getCommuteTime(dateA,dateB,timeA,timeB):
    return round((dt.datetime.combine(dateB,timeB) - dt.datetime.combine(dateA,timeA)).total_seconds()/60,0)

# %%
# Creating a new column which will store the time taken to move from airport to city and vice-versa
uber['Commute_minutes'] = uber.loc[~pd.isnull(uber['Drop_date'])].apply(lambda x: getCommuteTime(x['Req_date'],x['Drop_date'],x['Req_time'],x['Drop_time']), axis =1)
uber
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 9            267         City        2.0     Trip Completed
# 10          1467      Airport        2.0     Trip Completed
# 11          1983         City        2.0     Trip Completed
# 12          2784      Airport        2.0     Trip Completed
# 13          3075         City        2.0     Trip Completed
# 14          3379         City        2.0     Trip Completed
# ...

# %%
#Importing libraries for plotting
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
#plot showing distribution of time when cabs are requested
plt.hist(uber['Request_time_hours'])
plt.yscale('log')
plt.show()

# %%
#City to airport Requests being received based on Time slot category and their status
plt.figure(figsize = (15,5))
sns.countplot(x = 'RequestTimeSlotCategory', hue = 'Status', data = commute_df)

# %%
# plot showing distribution of days when cabs are requested
plt.hist(uber['Req_day'])
plt.yscale('log')

plt.show()

# %%
#plot show pickup point vs cab req time
plot1=uber.plot(x="Pickup point", y=["Request_time_hours"], kind="bar")
plt.yscale('log')
plt.show()

# %%
# The below plot shows the number of requests received every hour and their corresponding status
plt.figure(figsize=(15,5))
sns.set(style="darkgrid")
sns.countplot(x = 'Request_time_hours', hue = 'Status', data = uber)

# %%
#Hourly request rate to go from airport to city
plt.figure(figsize=(15,5))
commute_df = uber.loc[uber['Pickup point']=='Airport']
sns.countplot(x = 'Request_time_hours',data = commute_df)

# %%
#Hourly request rate to go from airport to city
plt.figure(figsize=(15,5))
commute_df = uber.loc[uber['Pickup point']=='City']
sns.countplot(x = 'Request_time_hours',data = commute_df)

# %%
# The below box plot shows that the commute time is highest at night and if we see the mean of the commute time
# at each time slot then its almost similar
sns.boxplot(y = 'Commute_minutes', x= 'RequestTimeSlotCategory', data = uber)
